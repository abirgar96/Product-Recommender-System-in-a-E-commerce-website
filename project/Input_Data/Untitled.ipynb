# %%
import pandas as pd

# %%
df=pd.read_csv("movie_ratings_data_set.csv",sep=",")
df.columns
# Out:
# Index(['user_id', 'movie_id', 'value'], dtype='object')

# %%
df.columns = ['user_id', 'product_id', 'value']

# %%
df.columns
# Out:
# Index(['user_id', 'product_id', 'value'], dtype='object')

# %%
df.head(5)
# Out:
#    user_id  product_id  value
# 0        1          28      4
# 1        1          26      4
# 2        1           9      4
# 3        1           1      4
# 4        1          14      4

# %%
df1=pd.read_csv("movie_ratings_data_set_training.csv",sep=",")
df1.columns = ['user_id', 'product_id', 'value']

# %%
df.to_csv("product_ratings_data_set.csv", index= False)

# %%
test=pd.read_csv("product_ratings_data_set.csv",sep=",")

# %%
df1.to_csv("product_ratings_data_set_training.csv", index= False)

# %%
df2=pd.read_csv("movie_ratings_data_set_testing.csv",sep=",")
df2.columns = ['user_id', 'product_id', 'value']
df2.head(5)
# Out:
#    user_id  product_id  value
# 0       32          13      5
# 1       26           8      5
# 2       70          30      5
# 3       66          19      4
# 4       38           3      5

# %%
df2.to_csv("product_ratings_data_set_testing.csv", index= False)

# %%
df3=pd.read_csv("movies.csv",sep=",")
df3
# Out:
#     movie_id                       title                          genre
# 0          1               The Sheriff 1           crime drama, western
# 1          2        The Big City Judge 1                    legal drama
# 2          3               The Sheriff 2           crime drama, western
# 3          4       Just a Regular Family                        reality
# 4          5        The Big City Judge 2                    legal drama
# 5          6           Attack on Earth 1                 sci-fi, action
# 6          7              The Secret Box       sci-fi, mystery, fantasy
# 7          8    Sci-Fi Murder Detectives          supernatural, mystery
# 8          9                 Biker Gangs            crime drama, action
# 9         10     Surrounded by Zombies 1         horror, zombie fiction
# 10        11           Inspector Jackson       detective drama, mystery
# 11        12                  Horrorfest                         horror
# ...

# %%
df3.columns = ['product_id', 'name', 'category']

# %%
df3.to_csv("products.csv", index= False)

# %%
df3
# Out:
#     product_id                        name                       category
# 0            1               The Sheriff 1           crime drama, western
# 1            2        The Big City Judge 1                    legal drama
# 2            3               The Sheriff 2           crime drama, western
# 3            4       Just a Regular Family                        reality
# 4            5        The Big City Judge 2                    legal drama
# 5            6           Attack on Earth 1                 sci-fi, action
# 6            7              The Secret Box       sci-fi, mystery, fantasy
# 7            8    Sci-Fi Murder Detectives          supernatural, mystery
# 8            9                 Biker Gangs            crime drama, action
# 9           10     Surrounded by Zombies 1         horror, zombie fiction
# 10          11           Inspector Jackson       detective drama, mystery
# 11          12                  Horrorfest                         horror
# ...
